# %% [markdown]
# ## Demo for Pytorch implementation of baseline

# %%
import sys

# Add main code-base to path
sys.path.append('../')

from util_rename import *
from model import ImgSegRefExpModel
import torch
import sys
import skimage.io
import numpy as np
import tensorflow as tf
import json
import timeit
from utl import eval_tools, im_processing
#import data
from data import ImageSegmentationDataset
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# trained model
pretrained_model_file = "/Users/shubhammehrotra/Downloads/text_objseg_pretrained_torch_converted_with_lstm"
vocab_file = './vocabulary_referit.txt'

root = '/Users/shubhammehrotra/text_objseg/exp-referit/'

image_dir = root + 'referit-dataset/images/'
mask_dir = root + 'referit-dataset/mask/'
query_file = root + 'data/referit_query_test.json'
bbox_file = root + 'data/referit_bbox.json'
imcrop_file = root + 'data/referit_imcrop.json'
imsize_file = root + 'data/referit_imsize.json'
vocab_file = root + 'data/vocabulary_referit.txt'

# %%
# Load vocabulary
vocab_dict = load_vocab_dict_from_file(vocab_file)

# Load model and weights
model = ImgSegRefExpModel(mlp_hidden=500, vocab_size=8803, emb_size=1000, lstm_hidden_size=1000)
pre_trained = torch.load(pretrained_model_file)
model.load_state_dict(pre_trained)

# %%
set(model.state_dict().keys()).difference(set(pre_trained.keys()))
# Out:
# set()

# %%
train_dataset = ImageSegmentationDataset(query_file, image_dir, mask_dir)
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
sum_I = 0
sum_U = 0

# %%
for batch_idx, (image, text, mask, original_image) in enumerate(train_loader):
    print (batch_idx)
    text = text.long()
    output_mask = model((image, text))
    
    labels = mask.cpu().detach().numpy() > 0
        
    #print("Mask shape", output_mask.shape)
    output_mask = output_mask.squeeze(0)
    output_mask = output_mask.squeeze(0)
    #print("Mask shape squeezed", output_mask.shape)
    
    q = ""
    for digit in original_image[0]:
        #print (digit.item())
        q += str(digit.item())

    #print (int (q))
    im = skimage.io.imread('/Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/' + q + '.jpg')

    # Final prediction
    prediction = resize_and_crop(output_mask.cpu().detach().numpy() > 0, * im.shape[:2]).astype(np.bool)
    #print (prediction)
    prediction = im_processing.resize_and_crop(prediction, im.shape[0], im.shape[1])
    I, U = eval_tools.compute_mask_IU(prediction, labels)
    sum_I += I
    sum_U += U
    print ('Updated IOU', float(sum_I)/sum_U)



print ('Final IOU', float(sum_I)/sum_U)
# Out:
# 15540
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/15540
# middle white building
# 0
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2471
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2471
# the person fartherest left
# 1
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2388
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2388
# the left part of the horizontal sidewalk closest to you on the left
# 2
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2602
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2602
# That magnificent creature.
# 3
# torch.Size([1, 1000, 16, 16])
# 16 16
# 27434
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/27434
# tree above left truck
# 4
# torch.Size([1, 1000, 16, 16])
# 16 16
# 22403
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/22403
# top row books
# 5
# torch.Size([1, 1000, 16, 16])
# 16 16
# 10792
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/10792
# sky
# 6
# torch.Size([1, 1000, 16, 16])
# 16 16
# 14048
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/14048
# The piece of red wood to the far left
# 7
# torch.Size([1, 1000, 16, 16])
# 16 16
# 20638
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/20638
# part of sand in front of all the people
# 8
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7975
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7975
# grey shirt guys bike, the bike
# 9
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18520
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18520
# yellow box nearest/slightly behind girl
# 10
# torch.Size([1, 1000, 16, 16])
# 16 16
# 12619
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/12619
# hammock the nearest person is on - the left part of the hammock
# 11
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11605
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11605
# sky
# 12
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1327
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1327
# far left chair
# 13
# torch.Size([1, 1000, 16, 16])
# 16 16
# 942
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/942
# left ground
# 14
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37526
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37526
# any sky
# 15
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2437
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2437
# green tree lower right
# 16
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11539
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11539
# plate of vegetables (anywhere)
# 17
# torch.Size([1, 1000, 16, 16])
# 16 16
# 22147
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/22147
# left man
# 18
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4812
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4812
# middle left railing.
# 19
# torch.Size([1, 1000, 16, 16])
# 16 16
# 38633
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/38633
# the wall on the left
# 20
# torch.Size([1, 1000, 16, 16])
# 16 16
# 27001
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/27001
# ground
# 21
# torch.Size([1, 1000, 16, 16])
# 16 16
# 20450
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/20450
# sky
# 22
# torch.Size([1, 1000, 16, 16])
# 16 16
# 6629
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/6629
# Middle figure, older man in khakis and a brown jacket
# 23
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4188
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4188
# man right
# 24
# torch.Size([1, 1000, 16, 16])
# 16 16
# 17742
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/17742
# airconditioner
# 25
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26776
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26776
# bottom center
# 26
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1804
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1804
# Grass on bottom left
# 27
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3280
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3280
# tree
# 28
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9675
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9675
# pile of clothes
# 29
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26708
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26708
# person far right
# 30
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18921
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18921
# tabletop lamp is on
# 31
# torch.Size([1, 1000, 16, 16])
# 16 16
# 24068
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/24068
# window center
# 32
# torch.Size([1, 1000, 16, 16])
# 16 16
# 24414
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/24414
# Bush front center
# 33
# torch.Size([1, 1000, 16, 16])
# 16 16
# 38215
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/38215
# sky
# 34
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7399
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7399
# large mountain on right
# 35
# torch.Size([1, 1000, 16, 16])
# 16 16
# 20917
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/20917
# floor bottome left corner
# 36
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4592
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4592
# my bad. boxes on right
# 37
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11667
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11667
# sky sliver
# 38
# torch.Size([1, 1000, 16, 16])
# 16 16
# 25286
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/25286
# 2nd white glass from left
# 39
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19902
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19902
# lamp on wall, closest to us
# 40
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4831
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4831
# the cacti above the animal
# 41
# torch.Size([1, 1000, 16, 16])
# 16 16
# 22932
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/22932
# skye
# 42
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1874
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1874
# sand
# 43
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1887
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1887
# sky above the wall
# 44
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3567
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3567
# rocks, bottom left
# 45
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39073
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39073
# very center of picture
# 46
# torch.Size([1, 1000, 16, 16])
# 16 16
# 22170
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/22170
# section of water that can be seen above the canoe between the guy in the middle and the guy on the right.
# 47
# torch.Size([1, 1000, 16, 16])
# 16 16
# 33510
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/33510
# ROCK*
# 48
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26993
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26993
# floor
# 49
# torch.Size([1, 1000, 16, 16])
# 16 16
# 21182
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/21182
# HAT
# 50
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1145
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1145
# clear sky to right
# 51
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11630
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11630
# mountain between city and sky
# 52
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31492
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31492
# middle building
# 53
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8491
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8491
# man with a leaf on his back
# 54
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26169
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26169
# right hand
# 55
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9107
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9107
# area above white roof
# 56
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11303
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11303
# bottom right corner
# 57
# torch.Size([1, 1000, 16, 16])
# 16 16
# 15418
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/15418
# building right
# 58
# torch.Size([1, 1000, 16, 16])
# 16 16
# 23820
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/23820
# rt trunk
# 59
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8017
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8017
# blood thing top right of crab
# 60
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8446
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8446
# top left thing
# 61
# torch.Size([1, 1000, 16, 16])
# 16 16
# 23017
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/23017
# Purple and green bush between openings.
# 62
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39052
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39052
# moutain with sun shining on it
# 63
# torch.Size([1, 1000, 16, 16])
# 16 16
# 22486
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/22486
# tile floor by girl in blue
# 64
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9731
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9731
# man
# 65
# torch.Size([1, 1000, 16, 16])
# 16 16
# 14026
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/14026
# grass below the person in the straw hat
# 66
# torch.Size([1, 1000, 16, 16])
# 16 16
# 32150
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/32150
# road
# 67
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18506
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18506
# left!
# 68
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9126
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9126
# mans face left side
# 69
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37634
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37634
# road
# 70
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8628
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8628
# snow board on the floor
# 71
# torch.Size([1, 1000, 16, 16])
# 16 16
# 15633
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/15633
# man in black
# 72
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7485
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7485
# rocks to right of lady
# 73
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3550
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3550
# bottom left
# 74
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37665
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37665
# MAN
# 75
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11249
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11249
# asphalt left side
# 76
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8164
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8164
# head of man in very front
# 77
# torch.Size([1, 1000, 16, 16])
# 16 16
# 38119
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/38119
# any portion of the city, middle part best
# 78
# torch.Size([1, 1000, 16, 16])
# 16 16
# 21869
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/21869
# left man
# 79
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8009
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8009
# building
# 80
# torch.Size([1, 1000, 16, 16])
# 16 16
# 27453
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/27453
# top rigth
# 81
# torch.Size([1, 1000, 16, 16])
# 16 16
# 12386
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/12386
# kid
# 82
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39117
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39117
# tree, right edge
# 83
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8251
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8251
# very top left mtn
# 84
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9779
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9779
# cargo on top of far right car
# 85
# torch.Size([1, 1000, 16, 16])
# 16 16
# 23528
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/23528
# sky
# 86
# torch.Size([1, 1000, 16, 16])
# 16 16
# 6238
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/6238
# patch of grass between the two cows and up slightly
# 87
# torch.Size([1, 1000, 16, 16])
# 16 16
# 20135
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/20135
# side on the bottom right
# 88
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8829
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8829
# hat
# 89
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39291
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39291
# bottom green
# 90
# torch.Size([1, 1000, 16, 16])
# 16 16
# 25574
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/25574
# the fat penguin laying down in between the two right in the middle
# 91
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39802
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39802
# water on right
# 92
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26733
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26733
# the trees to the top right
# 93
# torch.Size([1, 1000, 16, 16])
# 16 16
# 35596
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/35596
# bottom right corner
# 94
# torch.Size([1, 1000, 16, 16])
# 16 16
# 23065
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/23065
# clouds
# 95
# torch.Size([1, 1000, 16, 16])
# 16 16
# 12833
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/12833
# the wall on the left
# 96
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11072
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11072
# right person
# 97
# torch.Size([1, 1000, 16, 16])
# 16 16
# 716
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/716
# the kid on right in green stripe shirt
# 98
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8594
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8594
# table just upleft of her head
# 99
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8802
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8802
# first can in front
# 100
# torch.Size([1, 1000, 16, 16])
# 16 16
# 38242
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/38242
# middle window
# 101
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11470
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11470
# secodn bike from right in front
# 102
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26118
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26118
# black shirt on right
# 103
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26223
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26223
# tree leaves on right
# 104
# torch.Size([1, 1000, 16, 16])
# 16 16
# 14007
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/14007
# weird kid in front
# 105
# torch.Size([1, 1000, 16, 16])
# 16 16
# 27196
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/27196
# bottom rt corner
# 106
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8370
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8370
# sky
# 107
# torch.Size([1, 1000, 16, 16])
# 16 16
# 10030
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/10030
# her face
# 108
# torch.Size([1, 1000, 16, 16])
# 16 16
# 10022
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/10022
# People on the right
# 109
# torch.Size([1, 1000, 16, 16])
# 16 16
# 30958
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/30958
# sky
# 110
# torch.Size([1, 1000, 16, 16])
# 16 16
# 686
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/686
# kid looking at his hand on the left
# 111
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3322
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3322
# beach
# 112
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18050
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18050
# clouds top right
# 113
# torch.Size([1, 1000, 16, 16])
# 16 16
# 24833
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/24833
# ground bottom
# 114
# torch.Size([1, 1000, 16, 16])
# 16 16
# 40396
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/40396
# building
# 115
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9105
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9105
# person on far right blue shirt
# 116
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19047
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19047
# carpet
# 117
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1154
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1154
# green vines
# 118
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2620
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2620
# mid window left side
# 119
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9206
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9206
# person in black, front left
# 120
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8587
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8587
# HAT on woman second from right
# 121
# torch.Size([1, 1000, 16, 16])
# 16 16
# 25099
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/25099
# clouds in sky
# 122
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26967
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26967
# building
# 123
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18496
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18496
# hat
# 124
# torch.Size([1, 1000, 16, 16])
# 16 16
# 14192
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/14192
# center most instrument
# 125
# torch.Size([1, 1000, 16, 16])
# 16 16
# 27042
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/27042
# the duck on the right
# 126
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18146
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18146
# ocean
# 127
# torch.Size([1, 1000, 16, 16])
# 16 16
# 12961
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/12961
# wall behind man
# 128
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7669
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7669
# Ceiling (visible in upper right)
# 129
# torch.Size([1, 1000, 16, 16])
# 16 16
# 17267
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/17267
# people
# 130
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9105
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9105
# rocks above group
# 131
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1703
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1703
# fruit to the right that is bigger than other fruit toward the front of the photo
# 132
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8295
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8295
# blue sleeve
# 133
# torch.Size([1, 1000, 16, 16])
# 16 16
# 23017
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/23017
# the statue on top right
# 134
# torch.Size([1, 1000, 16, 16])
# 16 16
# 32767
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/32767
# sky
# 135
# torch.Size([1, 1000, 16, 16])
# 16 16
# 14426
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/14426
# tree trunk
# 136
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31660
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31660
# center face looking qat you
# 137
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37300
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37300
# bottom right
# 138
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7975
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7975
# rock under tree by lady black shirt
# 139
# torch.Size([1, 1000, 16, 16])
# 16 16
# 23297
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/23297
# 3 people at front- far right
# 140
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7210
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7210
# ground under individuals
# 141
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9425
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9425
# Hat of girl far legt
# 142
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19973
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19973
# the back of the seat above the sleepers
# 143
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31880
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31880
# guy in red
# 144
# torch.Size([1, 1000, 16, 16])
# 16 16
# 30219
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/30219
# sky
# 145
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3477
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3477
# tree on left side of yellow shack
# 146
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37834
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37834
# bottom ground
# 147
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37448
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37448
# top right
# 148
# torch.Size([1, 1000, 16, 16])
# 16 16
# 22832
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/22832
# mointain of skyline
# 149
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2877
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2877
# any part of the white water falls
# 150
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7600
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7600
# girl right
# 151
# torch.Size([1, 1000, 16, 16])
# 16 16
# 14707
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/14707
# anywhere on the boy
# 152
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7712
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7712
# the food
# 153
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31612
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31612
# you had it right the first time, sorry!  Grassy area in front of goal
# 154
# torch.Size([1, 1000, 16, 16])
# 16 16
# 12662
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/12662
# that fine ass chick
# 155
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31710
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31710
# trees top right
# 156
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11233
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11233
# mountain
# 157
# torch.Size([1, 1000, 16, 16])
# 16 16
# 10200
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/10200
# the stick tree
# 158
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18957
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18957
# table with black thing on it
# 159
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8030
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8030
# bottom left
# 160
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37797
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37797
# road
# 161
# torch.Size([1, 1000, 16, 16])
# 16 16
# 12143
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/12143
# sky upper left
# 162
# torch.Size([1, 1000, 16, 16])
# 16 16
# 24305
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/24305
# train, green part
# 163
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8950
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8950
# that metal thing at the top above the guys head
# 164
# torch.Size([1, 1000, 16, 16])
# 16 16
# 12879
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/12879
# bag next to the guy to the far right head
# 165
# torch.Size([1, 1000, 16, 16])
# 16 16
# 17732
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/17732
# ground between the horse's front and back legs
# 166
# torch.Size([1, 1000, 16, 16])
# 16 16
# 30270
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/30270
# sky
# 167
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11096
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11096
# man left
# 168
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8211
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8211
# Blue checker shirt chick
# 169
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1926
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1926
# tree on left
# 170
# torch.Size([1, 1000, 16, 16])
# 16 16
# 38820
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/38820
# mountain center
# 171
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37499
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37499
# 2nd
# 172
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31184
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31184
# sand
# 173
# torch.Size([1, 1000, 16, 16])
# 16 16
# 841
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/841
# desk
# 174
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3667
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3667
# horses butt that lady is on
# 175
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18174
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18174
# sky
# 176
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37638
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37638
# car
# 177
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8988
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8988
# hat
# 178
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2175
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2175
# very top of sky
# 179
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3859
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3859
# fucking god dude, under the beak
# 180
# torch.Size([1, 1000, 16, 16])
# 16 16
# 23386
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/23386
# garage door left
# 181
# torch.Size([1, 1000, 16, 16])
# 16 16
# 20750
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/20750
# flower
# 182
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1200
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1200
# right bed
# 183
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37346
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37346
# the front horse is a horse of course
# 184
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18519
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18519
# 2nd horse from left
# 185
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2020
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2020
# anywhere
# 186
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1312
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1312
# bed
# 187
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19310
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19310
# PPICTURE
# 188
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7984
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7984
# building on right
# 189
# torch.Size([1, 1000, 16, 16])
# 16 16
# 17790
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/17790
# road
# 190
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18391
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18391
# large cloud on left
# 191
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26886
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26886
# face
# 192
# torch.Size([1, 1000, 16, 16])
# 16 16
# 15606
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/15606
# sand left
# 193
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8870
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8870
# yellow building
# 194
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19315
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19315
# middle boat
# 195
# torch.Size([1, 1000, 16, 16])
# 16 16
# 35712
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/35712
# water..
# 196
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18096
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18096
# sky top left
# 197
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31186
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31186
# water
# 198
# torch.Size([1, 1000, 16, 16])
# 16 16
# 20017
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/20017
# sky
# 199
# torch.Size([1, 1000, 16, 16])
# 16 16
# 12050
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/12050
# right tall lamp
# 200
# torch.Size([1, 1000, 16, 16])
# 16 16
# 24054
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/24054
# rock person's hand is on
# 201
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37551
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37551
# lower left corner
# 202
# torch.Size([1, 1000, 16, 16])
# 16 16
# 40686
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/40686
# rock just below lions head
# 203
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37331
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37331
# blue sky
# 204
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2420
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2420
# green shrubs lower right
# 205
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8670
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8670
# green on left
# 206
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37383
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37383
# streewt on bottom
# 207
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37248
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37248
# bottom
# 208
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37371
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37371
# left side tree
# 209
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37106
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37106
# trees on right
# 210
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1238
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1238
# bush bottom left
# 211
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9260
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9260
# bottom
# 212
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37528
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37528
# sand at bottom
# 213
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37549
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37549
# pavement left of the bike
# 214
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39114
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39114
# very bottom
# 215
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31760
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31760
# its okay! Tennis court
# 216
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37498
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37498
# ground
# 217
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31293
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31293
# top left tree
# 218
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18490
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18490
# ceiling
# 219
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2483
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2483
# car
# 220
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2050
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2050
# guy in black jacket first
# 221
# torch.Size([1, 1000, 16, 16])
# 16 16
# 34151
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/34151
# sky
# 222
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9035
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9035
# tree top left
# 223
# torch.Size([1, 1000, 16, 16])
# 16 16
# 40657
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/40657
# branch koala is on
# 224
# torch.Size([1, 1000, 16, 16])
# 16 16
# 13625
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/13625
# flower
# 225
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4504
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4504
# steps
# 226
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1096
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1096
# wall directly to the right of gate
# 227
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4595
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4595
# middle peep
# 228
# torch.Size([1, 1000, 16, 16])
# 16 16
# 22309
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/22309
# top right corner
# 229
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1345
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1345
# lamp
# 230
# torch.Size([1, 1000, 16, 16])
# 16 16
# 14044
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/14044
# chicks face
# 231
# torch.Size([1, 1000, 16, 16])
# 16 16
# 24195
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/24195
# left girl
# 232
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7869
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7869
# under the table on right boxes
# 233
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11667
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11667
# sign
# 234
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9531
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9531
# water very bottom
# 235
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19298
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19298
# person under nose. right side
# 236
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3803
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3803
# center ice in the horizon
# 237
# torch.Size([1, 1000, 16, 16])
# 16 16
# 21485
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/21485
# person
# 238
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4248
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4248
# vase
# 239
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19791
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19791
# person on far left
# 240
# torch.Size([1, 1000, 16, 16])
# 16 16
# 22924
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/22924
# far left water
# 241
# torch.Size([1, 1000, 16, 16])
# 16 16
# 40020
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/40020
# treee trunks right side of picture
# 242
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8370
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8370
# person on the far left
# 243
# torch.Size([1, 1000, 16, 16])
# 16 16
# 33467
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/33467
# rock jutting out of water, the fattest one near the shore in back
# 244
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2093
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2093
# ground to right of alpaca
# 245
# torch.Size([1, 1000, 16, 16])
# 16 16
# 16523
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/16523
# people
# 246
# torch.Size([1, 1000, 16, 16])
# 16 16
# 38092
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/38092
# left ship closest to us
# 247
# torch.Size([1, 1000, 16, 16])
# 16 16
# 5206
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/5206
# sea
# 248
# torch.Size([1, 1000, 16, 16])
# 16 16
# 21624
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/21624
# sky without smoke
# 249
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8830
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8830
# sky
# 250
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3035
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3035
# birds
# 251
# torch.Size([1, 1000, 16, 16])
# 16 16
# 30878
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/30878
# TOP LEFT
# 252
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7319
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7319
# water
# 253
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18142
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18142
# clouds
# 254
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2886
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2886
# bottom, to the left or right of road
# 255
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8660
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8660
# the green tree on the left
# 256
# torch.Size([1, 1000, 16, 16])
# 16 16
# 16775
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/16775
# right man
# 257
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3123
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3123
# water
# 258
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18358
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18358
# any part of building
# 259
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19402
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19402
# the water to the left of the leftmost person head
# 260
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8818
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8818
# sky
# 261
# torch.Size([1, 1000, 16, 16])
# 16 16
# 10714
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/10714
# grass bottom right
# 262
# torch.Size([1, 1000, 16, 16])
# 16 16
# 27613
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/27613
# flowers - just above water center
# 263
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19271
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19271
# sticks bottom right
# 264
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4574
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4574
# top right
# 265
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39829
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39829
# ground
# 266
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7257
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7257
# haha area between her head and the waterfall
# 267
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11060
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11060
# big cloud
# 268
# torch.Size([1, 1000, 16, 16])
# 16 16
# 20830
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/20830
# red part of sky
# 269
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1420
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1420
# right green building
# 270
# torch.Size([1, 1000, 16, 16])
# 16 16
# 15417
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/15417
# leftmost bench
# 271
# torch.Size([1, 1000, 16, 16])
# 16 16
# 13248
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/13248
# sky
# 272
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9403
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9403
# counter
# 273
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4164
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4164
# boys pants
# 274
# torch.Size([1, 1000, 16, 16])
# 16 16
# 21315
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/21315
# man in white left side
# 275
# torch.Size([1, 1000, 16, 16])
# 16 16
# 30097
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/30097
# road
# 276
# torch.Size([1, 1000, 16, 16])
# 16 16
# 15765
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/15765
# horse butt on right
# 277
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2562
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2562
# cloud upper left
# 278
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39550
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39550
# bottom
# 279
# torch.Size([1, 1000, 16, 16])
# 16 16
# 11343
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/11343
# to the left of the large stone, the tiny square of sky above the mountains in the distance
# 280
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26113
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26113
# the land part
# 281
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4718
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4718
# white sign
# 282
# torch.Size([1, 1000, 16, 16])
# 16 16
# 31651
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/31651
# open hand on telephone booth
# 283
# torch.Size([1, 1000, 16, 16])
# 16 16
# 26034
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/26034
# lamp above left bed
# 284
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7548
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7548
# 2nd to left backpack on ground, blue stripe, next to man's leg
# 285
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8689
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8689
# black part of the doorway NOT the guy
# 286
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39513
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39513
# right sky
# 287
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37832
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37832
# red shorts
# 288
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9320
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9320
# woman
# 289
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1100
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1100
# dark floor
# 290
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37204
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37204
# bottom left snow
# 291
# torch.Size([1, 1000, 16, 16])
# 16 16
# 23853
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/23853
# bike
# 292
# torch.Size([1, 1000, 16, 16])
# 16 16
# 30136
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/30136
# The car with the green sticker
# 293
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7377
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7377
# grass
# 294
# torch.Size([1, 1000, 16, 16])
# 16 16
# 38762
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/38762
# left most part of screen, not bottom
# 295
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8030
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8030
# portion of brick wall on far right
# 296
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9493
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9493
# bottom right
# 297
# torch.Size([1, 1000, 16, 16])
# 16 16
# 16857
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/16857
# upper right
# 298
# torch.Size([1, 1000, 16, 16])
# 16 16
# 22057
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/22057
# bottom right corner
# 299
# torch.Size([1, 1000, 16, 16])
# 16 16
# 1960
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/1960
# the white "ceiling" area of the building
# 300
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18435
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18435
# pond
# 301
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18085
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18085
# white patch of sky under cloud
# 302
# torch.Size([1, 1000, 16, 16])
# 16 16
# 20743
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/20743
# middle woman
# 303
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7062
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7062
# bottle under man in red in center
# 304
# torch.Size([1, 1000, 16, 16])
# 16 16
# 17766
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/17766
# grass
# 305
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9290
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9290
# water at the top left
# 306
# torch.Size([1, 1000, 16, 16])
# 16 16
# 16045
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/16045
# lamp top one
# 307
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4822
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4822
# person on very right
# 308
# torch.Size([1, 1000, 16, 16])
# 16 16
# 37543
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/37543
# asphalt
# 309
# torch.Size([1, 1000, 16, 16])
# 16 16
# 8651
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/8651
# pot only, light one toward middle
# 310
# torch.Size([1, 1000, 16, 16])
# 16 16
# 4717
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/4717
# the sky
# 311
# torch.Size([1, 1000, 16, 16])
# 16 16
# 35944
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/35944
# left most side
# 312
# torch.Size([1, 1000, 16, 16])
# 16 16
# 2471
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/2471
# buildings
# 313
# torch.Size([1, 1000, 16, 16])
# 16 16
# 7247
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/7247
# trees in lower right corner
# 314
# torch.Size([1, 1000, 16, 16])
# 16 16
# 19679
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/19679
# the green part of the tree above the man
# 315
# torch.Size([1, 1000, 16, 16])
# 16 16
# 40486
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/40486
# brick ground
# 316
# torch.Size([1, 1000, 16, 16])
# 16 16
# 23966
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/23966
# grass left of rail
# 317
# torch.Size([1, 1000, 16, 16])
# 16 16
# 3105
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/3105
# bottom right corner
# 318
# torch.Size([1, 1000, 16, 16])
# 16 16
# 39871
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/39871
# ground left corner
# 319
# torch.Size([1, 1000, 16, 16])
# 16 16
# 38135
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/38135
# building right of triangle building
# 320
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9191
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9191
# ground
# 321
# torch.Size([1, 1000, 16, 16])
# 16 16
# 25574
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/25574
# most front penguin facing this way
# 322
# torch.Size([1, 1000, 16, 16])
# 16 16
# 21567
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/21567
# mountains far right
# 323
# torch.Size([1, 1000, 16, 16])
# 16 16
# 9089
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/9089
# stairs
# 324
# torch.Size([1, 1000, 16, 16])
# 16 16
# 12000
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/12000
# GROUND
# 325
# torch.Size([1, 1000, 16, 16])
# 16 16
# 18162
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/18162
# big tree left of center
# 326
# torch.Size([1, 1000, 16, 16])
# 16 16
# 21786
# Image /Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/21786
# tree top left
# 327
# torch.Size([1, 1000, 16, 16])
# 16 16
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-e6ca781238ee> in <module>
#      23     #print (prediction)
#      24     prediction = im_processing.resize_and_crop(prediction, im.shape[0], im.shape[1])
# ---> 25     I, U = eval_tools.compute_mask_IU(prediction, labels)
#      26     sum_I += I
#      27     sum_U += U
#
# ~/ImgSegRefExp/utl/eval_tools.py in compute_mask_IU(masks, target)
#       8 # # all boxes are [num, height, width] binary array
#       9 def compute_mask_IU(masks, target):
# ---> 10     assert(target.shape[-2:] == masks.shape[-2:])
#      11     I = np.sum(np.logical_and(masks, target))
#      12     U = np.sum(np.logical_or(masks, target))
#
# AssertionError:

# %%
#Displaying output
   
im = skimage.io.imread('/Users/shubhammehrotra/text_objseg/exp-referit/referit-dataset/images/' + q + '.jpg')

    # Final prediction
prediction = resize_and_crop(output_mask.cpu().detach().numpy() > 0, * im.shape[:2]).astype(np.bool)
#print (prediction)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(im)
plt.subplot(1, 2, 2)
plt.imshow(prediction)
print (labels.shape, prediction.shape)
print ()
prediction = im_processing.resize_and_crop(prediction, im.shape[0], im.shape[1])
I, U = eval_tools.compute_mask_IU(prediction, labels)

print ('IOU',  I/U)


#         # Evaluate the segmentation performance of using bounding box segmentation
#         pred_raw = (scores_val >= score_thresh).astype(np.float32)
#         predicts = im_processing.resize_and_crop(pred_raw, im.shape[0], im.shape[1])
#         I, U = eval_tools.compute_mask_IU(predicts, labels)
#         cum_I += I
#         cum_U += U
#         this_IoU = I/U

#print("query text = '%s'" % query)
# Out:
# (1, 360, 480) (360, 480)
#
# IOU 0.07157096006687673

# %%
original_image_name = "12346"
char = []
    
char = [int(i) for i in original_image_name]

char = torch.from_numpy(np.array(char))

q = ""
for digit in s:
    print (digit)
    q += str(digit)

print (int (q))
# Out:
# 1
# 2
# 3
# 4
# 6
# 12346

# %% [markdown]
# ### Run on sample image

# %%
# input image and query text
im_file = './38100.jpg'
query = 'sky above the bridge'

# %%
# Load the model
# Model Param
T = 20
N = 1
input_H = 512; featmap_H = (input_H // 32)
input_W = 512; featmap_W = (input_W // 32)
num_vocab = 8803
embed_dim = 1000
lstm_dim = 1000
mlp_hidden_dims = 500

channel_mean = np.array([123.68, 116.779, 103.939], dtype=np.float32)

# Run on the input image and query text
text_seq_val = np.zeros((T, N), dtype=np.float32)
imcrop_val = np.zeros((N, input_H, input_W, 3), dtype=np.float32)

# Preprocess image and text
im = skimage.io.imread(im_file)

# Makes it uint8
processed_im = skimage.img_as_ubyte(resize_and_pad(im, input_H, input_W))
print(processed_im.dtype)

imcrop_val[0, :] = processed_im.astype(np.float32) - channel_mean
print(imcrop_val.dtype)

# preprocess sentence pads 0's before the phrase. flipping it ruins the output
text_seq_val[:, 0] = preprocess_sentence(query, vocab_dict, T)
print(text_seq_val.dtype)
print (text_seq_val)

imcrop_val = torch.Tensor(imcrop_val).permute(0, 3, 1, 2) 
text_seq_val = torch.LongTensor(text_seq_val).t()

# %%
print(imcrop_val.shape)
print(text_seq_val.shape)

# %%
# Forward pass to get response map
output_mask = model((imcrop_val, text_seq_val))

print("Mask shape", output_mask.shape)
output_mask = output_mask.squeeze(0)
output_mask = output_mask.squeeze(0)
print("Mask shape squeezed", output_mask.shape)

# Final prediction
prediction = resize_and_crop(output_mask.cpu().detach().numpy() > 0, * im.shape[:2]).astype(np.bool)

# %%
prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c3d8c93f720f> in <module>
# ----> 1 prediction
#
# NameError: name 'prediction' is not defined

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(im)
plt.subplot(1, 2, 2)
plt.imshow(prediction)

print("query text = '%s'" % query)
# Out:
# query text = 'sky above the bridge'
